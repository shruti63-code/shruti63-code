# %% [markdown]
# <a href="https://colab.research.google.com/github/shruti63-code/shruti63-code/blob/main/Business_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# solving a business problem using optimization techniques

# %%
# Solving a Business Problem Using Linear Programming

# Example Business Problem:
# A factory produces two types of products: A and B.
# - Each unit of product A gives a profit of $20, and each unit of product B gives a profit of $30.
# - Producing one unit of product A requires 3 hours of labor and 1 unit of raw material.
# - Producing one unit of product B requires 2 hours of labor and 2 units of raw material.
# - The factory has a maximum of 12 hours of labor and 8 units of raw material available.
# Goal: Maximize profit while satisfying resource constraints.

# !pip install pulp
from pulp import LpMaximize, LpProblem, LpVariable, lpSum

# Step 1: Define the Linear Programming Problem
problem = LpProblem("Maximize_Factory_Profit", LpMaximize)
# Out:
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 76.9 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0

# %%
# Step 2: Define Decision Variables
x = LpVariable("Product_A", lowBound=0, cat="Continuous")  # Number of units of Product A
y = LpVariable("Product_B", lowBound=0, cat="Continuous")  # Number of units of Product B

# %%
# Step 3: Define the Objective Function
# Maximize profit = 20x + 30y
problem += 20 * x + 30 * y, "Total_Profit"

# %%
# Step 6: Display Results
print("Status:", problem.status)
print("Optimal Solution:")
print(f"Product A: {x.varValue}")
print(f"Product B: {y.varValue}")
print(f"Maximum Profit: ${problem.objective.value()}")
# Out:
# Status: 0
# Optimal Solution:
# Product A: None
# Product B: None
# Maximum Profit: $None

# %%
# Visualization (Optional)
import matplotlib.pyplot as plt
import numpy as np

# Define lines for constraints and objective function
labor_x = np.linspace(0, 5, 100)
labor_y = (12 - 3 * labor_x) / 2
material_y = (8 - labor_x) / 2


plt.figure(figsize=(8, 6))
plt.plot(labor_x, labor_y, label="Labor Constraint (3x + 2y <= 12)")
plt.plot(labor_x, material_y, label="Material Constraint (x + 2y <= 8)")
plt.fill_between(labor_x, np.minimum(labor_y, material_y), 0, color="gray", alpha=0.3, label="Feasible Region")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)


plt.xlabel("Product A")
plt.ylabel("Product B")
plt.title("Linear Programming - Feasible Region and Optimal Solution")
plt.legend()
plt.grid()
plt.show()
